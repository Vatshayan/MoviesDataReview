# %%
#Made by Shivam Vatshayan(vatshayanshiv1998@gmail.com)

# %%
import pandas as pd

# %%
import numpy as np

# %%
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
movies=pd.read_csv("movies.csv")

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9125 entries, 0 to 9124
# Data columns (total 3 columns):
# movieId    9125 non-null int64
# title      9125 non-null object
# genres     9125 non-null object
# dtypes: int64(1), object(2)
# memory usage: 142.6+ KB

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movies.tail()
# Out:
#       movieId                                              title  \
# 9120   162672                                Mohenjo Daro (2016)
# 9121   163056                               Shin Godzilla (2016)
# 9122   163949  The Beatles: Eight Days a Week - The Touring Y...
# 9123   164977                           The Gay Desperado (1936)
# 9124   164979                              Women of '69, Unboxed
#
#                                genres
# 9120          Adventure|Drama|Romance
# 9121  Action|Adventure|Fantasy|Sci-Fi
# 9122                      Documentary
# 9123                           Comedy
# 9124                      Documentary

# %%
movies.head(9124)
# Out:
#       movieId                                              title  \
# 0           1                                   Toy Story (1995)
# 1           2                                     Jumanji (1995)
# 2           3                            Grumpier Old Men (1995)
# 3           4                           Waiting to Exhale (1995)
# 4           5                 Father of the Bride Part II (1995)
# 5           6                                        Heat (1995)
# 6           7                                     Sabrina (1995)
# 7           8                                Tom and Huck (1995)
# 8           9                                Sudden Death (1995)
# 9          10                                   GoldenEye (1995)
# 10         11                     American President, The (1995)
# 11         12                 Dracula: Dead and Loving It (1995)
# 12         13                                       Balto (1995)
# ...

# %%
movies.describe()
# Out:
#              movieId
# count    9125.000000
# mean    31123.291836
# std     40782.633604
# min         1.000000
# 25%      2850.000000
# 50%      6290.000000
# 75%     56274.000000
# max    164979.000000

# %%
movies.hist()
plt.show()

# %%
scatter_matrix(movies)
plt.show()

# %%
plt.figure(figsize=(7,4))
sns.heatmap(movies.corr(), annot=True, cmap='cubehelix_r')
plt.show()

# %%
movies.hist(edgecolor='black', linewidth=5.5)
fig=plt.gcf()

plt.show()

# %%
train, test = train_test_split(movies, test_size = 0.25)
print(train.shape)
print(test.shape)
# Out:
# (6843, 3)
# (2282, 3)
